# %%
import numpy as np
from math import comb
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
## hw 10
x = np.linspace(-1, 1, 10000)

P_0 = np.ones_like(x)
P_1 = x
P_2 = x**2 - 1/3
P_3 = x**3 - 3/5*x
P_4 = x**4 - 6/7*x**2 +3/35

plt.plot(x, P_0, 'r')
plt.plot(x, P_1, 'g')
plt.plot(x, P_2, 'b')
plt.plot(x, P_3, 'purple')
plt.plot(x, P_4, 'brown')
plt.plot(x, np.zeros_like(x), 'black')
